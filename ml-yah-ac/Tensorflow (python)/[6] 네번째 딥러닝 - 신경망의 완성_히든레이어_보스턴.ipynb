# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 1. 과거의 데이터를 준비합니다.
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)
print(보스턴.columns)
보스턴.head()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
# 독립변수, 종속변수 분리
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]

print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 2. 모델의 구조를 만듭니다.
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(10, activation='swish')(X)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X , Y)
model.compile(loss='mse')

# %%
# 모델 구조 확인
model.summary() # (13+1)*10 = 140, (10+1)*1 = 11
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 3. 데이터로 모델을 학습(fit)합니다.
model.fit(독립, 종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 20.8308
# Epoch 2/10
# 16/16 [==============================] - 0s 859us/step - loss: 21.2457
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 20.7136
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 19.7955
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 20.3419
# Epoch 6/10
# 16/16 [==============================] - 0s 697us/step - loss: 20.0288
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 20.9152
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 20.8065
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 21.1663
# Epoch 10/10
# 16/16 [==============================] - 0s 943us/step - loss: 20.3872

# %%
# 4. 모델을 이용합니다.
print(model.predict(독립[0:5]))
# Out:
# [[28.82586 ]
#  [23.279072]
#  [30.78901 ]
#  [29.601213]
#  [28.70859 ]]

# %%
# 종속변수 확인
print(종속[0:5])
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
weights = model.get_weights()
print(weights)
# Out:
# [array([[-1.85710013e-01,  2.82310009e-01,  3.07102680e-01,
#         -5.06769300e-01,  1.81607127e-01,  3.44426811e-01,
#         -3.91890347e-01,  4.50409085e-01, -2.73461282e-01,
#          1.38865173e-01],
#        [ 8.23310390e-02,  2.85754383e-01,  1.38684750e-01,
#         -7.12828279e-01, -4.65000808e-01,  1.41472876e-01,
#          4.21928406e-01, -1.98829144e-01,  5.09890139e-01,
#         -1.84286118e-01],
#        [-9.68263373e-02,  8.44556093e-03,  1.00975692e-01,
#          1.13820958e+00, -1.32557720e-01,  3.03967595e-02,
#         -3.58893454e-01, -1.21203281e-01, -5.06999075e-01,
#         -4.46828604e-01],
#        [ 2.17246318e+00,  2.34538794e-01, -3.08688045e-01,
#         -5.22986829e-01, -1.66563988e-02, -1.21519327e-01,
#          4.08684969e-01,  1.09233066e-01, -1.16846651e-01,
#         -3.37873459e-01],
#        [ 1.15704608e+00, -2.49170661e-01, -3.69424999e-01,
#         -3.28597054e-03,  4.84631717e-01,  2.16641903e-01,
#         -3.32072556e-01, -2.71667898e-01, -2.87053585e-01,
#          1.92562938e-01],
#        [ 3.83149219e+00,  1.71759903e-01,  2.86530554e-01,
#          1.45523548e+00, -1.77255899e-01,  4.73960757e-01,
#          2.12276161e-01, -2.38949716e-01,  6.63158894e-02,
#         -1.43867761e-01],
#        [ 7.26494268e-02,  4.28653598e-01,  1.22115910e-01,
#         -8.92521918e-01, -4.03091043e-01,  4.60918605e-01,
#          1.17342293e-01,  2.80962825e-01, -3.85269821e-02,
#         -4.59770024e-01],
#        [-6.52119637e-01, -3.48989785e-01, -4.80457246e-01,
#          1.24235362e-01, -3.46395880e-01, -2.86320388e-01,
#          4.58829463e-01, -3.36493701e-01, -2.35096604e-01,
#          1.01234317e-01],
#        [ 1.60368502e-01, -4.19148207e-01,  4.75450277e-01,
#         -2.04171330e-01,  3.80226672e-01,  2.53400207e-02,
#          1.10162973e-01,  3.10290724e-01,  1.92863703e-01,
#          4.02849793e-01],
#        [-2.65012868e-02, -3.93350542e-01, -3.55867028e-01,
#          2.11239636e-01, -3.51112396e-01, -1.79071575e-01,
#         -2.12604374e-01, -3.46491277e-01, -3.23165804e-01,
#         -4.25944358e-01],
#        [-4.65979457e-01, -1.36595368e-02, -8.51069391e-02,
#          4.30118918e-01,  2.14594245e-01,  3.47547472e-01,
#          2.58318126e-01, -3.88271272e-01, -1.31503761e-01,
#         -4.98383850e-01],
#        [ 9.41152032e-03, -1.72719359e-01, -3.13328475e-01,
#          1.86892413e-03, -4.86969680e-01, -2.23074436e-01,
#         -2.23305672e-01,  1.22287326e-01, -1.25644147e-01,
#         -4.85089004e-01],
#        [-3.95288795e-01, -1.58889592e-02, -2.55588114e-01,
#         -9.90717590e-01, -3.26858222e-01, -1.96791261e-01,
#          2.74144411e-01,  1.43235192e-01, -1.41820133e-01,
#         -2.55454034e-01]], dtype=float32), array([ 1.8191981e+00,  0.0000000e+00,  0.0000000e+00,  1.1096139e+00,
#         0.0000000e+00, -5.6060712e-09, -2.9709488e-24, -7.6744013e-02,
#        -1.9394038e-23,  0.0000000e+00], dtype=float32), array([[ 1.3364531 ],
#        [ 0.292638  ],
#        [-0.2696091 ],
#        [ 0.12709093],
#        [-0.35382786],
#        [ 0.22111177],
#        [-0.22428745],
#        [-4.578186  ],
#        [-0.5619818 ],
#        [ 0.37803775]], dtype=float32), array([3.932406], dtype=float32)]

# %%
print(len(weights))
# Out:
# 4

# %%
for i in range(4):
  print(weights[i].shape)
# Out:
# (13, 10)
# (10,)
# (10, 1)
# (1,)
