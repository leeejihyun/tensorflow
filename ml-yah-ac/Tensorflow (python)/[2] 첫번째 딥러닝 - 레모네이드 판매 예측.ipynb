# %% [markdown]
# https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv

# %%
# 라이브러리 사용
import pandas as pd
import tensorflow as tf

# %%
# 데이터 준비
레몬에이드 = pd.read_csv("https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv")
레몬에이드.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
# 종속변수, 독립변수
독립 = 레몬에이드[['온도']]
종속 = 레몬에이드[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
# 모델을 만듭니다.
X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
# 모델을 학습합니다.
model.fit(독립, 종속, epochs=10000, verbose=0)

# %%
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4492e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 6ms/step - loss: 1.4477e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4474e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4478e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4477e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4485e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4495e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4496e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4493e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4499e-04

# %%
# 모델을 이용합니다.
model.predict(독립)
# Out:
# array([[40.01429 ],
#        [42.013348],
#        [44.012405],
#        [46.011467],
#        [48.010525],
#        [50.009583]], dtype=float32)

# %%
종속
# Out:
#    판매량
# 0   40
# 1   42
# 2   44
# 3   46
# 4   48
# 5   50

# %%
model.predict([[15]])
# Out:
# array([[30.01899]], dtype=float32)
