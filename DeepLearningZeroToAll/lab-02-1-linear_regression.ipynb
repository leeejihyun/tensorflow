# %% [markdown]
# # Lab-02-1 linear regression

# %%
# %tensorflow_version 1.x

import tensorflow as tf
tf.set_random_seed(777)  # for reprducibilty
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ## X and Y data

# %%
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# %% [markdown]
# ## Variable

# %%
# Try to find value for W and b to compute y_data = x_data * W + b  
# We know that W should be 1 and b should be 0
# But let's TensorFlow figure it out 
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# ## Our Model

# %%
# Out hypothesis XW+b
hypothesis = x_train * W + b

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %% [markdown]
# ## Minimize

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %% [markdown]
# ## Prepare session

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

# %% [markdown]
# ## Fit the line

# %%
for step in range(2001):
    sess.run(train)
    if step % 200 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 2.8232925 [2.1286771] [-0.8523567]
# 200 0.06996683 [1.3072149] [-0.69837123]
# 400 0.026716756 [1.18984] [-0.43155095]
# 600 0.010201763 [1.1173096] [-0.26667225]
# 800 0.0038955389 [1.0724903] [-0.1647873]
# 1000 0.0014875144 [1.0447947] [-0.10182866]
# 1200 0.00056800124 [1.0276803] [-0.06292386]
# 1400 0.00021689285 [1.0171049] [-0.03888334]
# 1600 8.2820945e-05 [1.0105698] [-0.02402755]
# 1800 3.162432e-05 [1.0065314] [-0.01484743]
# 2000 1.2076169e-05 [1.0040361] [-0.00917495]

# %% [markdown]
# #### Learns best fit W:[ 1.], b:[  0.]
#
# ```
# 0 3.51465 [-0.03875808] [ 0.40560108]
# 200 0.0286106 [ 0.80354649] [ 0.44658491]
# 400 0.010925 [ 0.87860364] [ 0.27596244]
# 600 0.00417169 [ 0.92498434] [ 0.17052816]
# 800 0.00159296 [ 0.95364493] [ 0.10537602]
# 1000 0.000608266 [ 0.97135544] [ 0.06511588]
# 1200 0.000232263 [ 0.98229945] [ 0.04023758]
# 1400 8.86917e-05 [ 0.98906201] [ 0.02486444]
# 1600 3.38653e-05 [ 0.99324113] [ 0.01536462]
# 1800 1.2932e-05 [ 0.99582338] [ 0.00949448]
# 2000 4.9383e-06 [ 0.99741906] [ 0.00586706]
# ```
